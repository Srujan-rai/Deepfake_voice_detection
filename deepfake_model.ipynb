# %% [markdown]
# <a href="https://colab.research.google.com/github/Srujan-rai/Deepfake_voice_detection/blob/main/deepfake_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
data_dir='/content/drive/MyDrive/Deepfake/Deepfake - Voice Detection/KAGGLE/DATA'

# %%
os.listdir(data_dir)
# Out:
# ['REAL_20SEC_IMG', 'FAKE_20SEC_IMG']

# %%
os.listdir(os.path.join(data_dir,'FAKE_20SEC_IMG'))
# Out:
# ['FAKE_20SEC_IMG']

# %%
os.listdir(os.path.join(data_dir,'REAL_20SEC_IMG'))
# Out:
# ['biden-original_10sec_waveform.png',
#  'linus-original_10sec_waveform.png',
#  'margot-original_10sec_waveform.png',
#  'musk-original_10sec_waveform.png',
#  'obama-original_10sec_waveform.png',
#  'ryan-original_10sec_waveform.png',
#  'taylor-original_10sec_waveform.png',
#  'trump-original_10sec_waveform.png']

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras

# %%
data=tf.keras.utils.image_dataset_from_directory('/content/drive/MyDrive/Deepfake/Deepfake - Voice Detection/KAGGLE/DATA')
# Out:
# Found 64 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch=data_iterator.next()

# %%
len(batch)
# Out:
# 2

# %%
fig,ax=plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:3]):
  ax[idx].imshow(img.astype(int))
  ax[idx].title.set_text(batch[1][idx])

# %%
#preprocess data
scaled=batch[0]/255
scaled.max()
# Out:
# 1.0

# %%
data=data.map(lambda x, y:(x/255,y))

# %%
scaled_iterator=data.as_numpy_iterator().next()
